# %% [markdown]
# # Project 1
# ## Modelling motor proteins as particles diffusing in parallel potentials
# ### Abnar, S., Nilsen F., Rødde, M.

# %% [markdown]
# # 3. Exercises
#
# <div class="alert alert-block alert-info">Exercise 3.1</div>
#
# Showing that (1)
#
# $$
# \phi(x,t)=\frac{1}{\sqrt{4\pi Dt}} \int_{-\infty}^\infty \mathrm{d}y \, h(y)e^{-\frac{(x-y)^2}{4Dt}}
# $$
#
# is a solution of the diffusion equation (2)
#
# $$
# \frac{\partial \phi(x,t)}{\partial t} =  D \frac{\partial^2 \phi(x,t)}{\partial x^2}
# $$

# %% [markdown]
# Differentiating (1) with respect to time $t$
#
# $$
# \frac{ \partial \phi(x,t)}{\partial t} = \frac{ \partial}{\partial t} \left[\frac{1}{\sqrt{4\pi Dt}} \int_{\text{-}\infty}^\infty \mathrm{d}y \, h(y)e^{\,\text{-}\frac{(x-y)^2}{4Dt}} \right]
# $$
#
# where  $\left(4\pi D\right)^{\,\text{-}1/2}$ and $h(y)$ is independent of time. We simplify to
#
# $$
# \frac{ \partial \phi(x,t)}{\partial t} = \frac{ \partial}{\partial t} \left[\frac{1}{\sqrt{t}} e^{\,\text{-}\frac{(x-y)^2}{4Dt}} \right]  \int_{\text{-}\infty}^\infty \mathrm{d}y \, \frac{1}{\sqrt{4\pi D}}\, h(y)
# $$
#
# and can hereby use product rule of derivation. We define
#
# $$
# u \equiv \frac{1}{\sqrt{t}},
# $$
#
# $$
# v \equiv e^{\text{-} \frac{(x-y)^2}{4Dt}},
# $$
#
# and
#
# $$
# A \equiv \int_{\text{-}\infty}^\infty \mathrm{d}y \, \frac{1}{\sqrt{4\pi D}} \, h(y),
# $$
#
# Where $A$ is independent of time. Thus, the derivation simplifies to
#
# $$
# \frac{ \partial \phi(x,t)}{\partial t} = \, \left[ \frac{\partial u}{\partial t} v \, + \, \frac{\partial v}{\partial t} u \right] \cdot A
# $$
#
# with the following solutions
#
# $$
# \frac{\partial u}{\partial t} = \frac{\text{-}1}{2 \, t^{\,3/2}},
# $$
#
# $$
# \frac{\partial v}{\partial t} = \frac{(x-y)^2}{4Dt^2} e^{\,\text{-}\frac{(x-y)^2}{4Dt}}
# $$
#
# Thus, we have obtained the following expression for the substance distribution differentiated with respect to time
#
# $$
# \frac{ \partial \phi(x,t)}{\partial t} = \,   \left[ \frac{\text{-}1}{2 \, t^{\,3/2}} e^{\text{-} \frac{(x-y)^2}{4Dt}} \, + \, \frac{(x-y)^2}{4Dt^2} e^{\,\text{-}\frac{(x-y)^2}{4Dt}} \frac{1}{\sqrt{t}} \right] \cdot  \,A
# $$
#
# which can be simplified to
#
# $$
# \frac{ \partial \phi(x,t)}{\partial t} = \, \left(\frac{(x-y)^2}{4Dt^2}  \, + \, \frac{\text{-}1}{2 t}  \right) e^{\,\text{-}\frac{(x-y)^2}{4Dt}} \, \int_{\text{-}\infty}^\infty \mathrm{d}y\,\frac{1}{\sqrt{4\pi Dt}} \, h(y)
# $$
#
#
#
# The term of the second derivative of the distribution with respect to position similarly becomes
#
# $$
# D \frac{\partial^2 \phi(x,t)}{\partial x^2} = \frac{1}{4Dt^2} \left( \left(x-y\right)^2 - 2Dt \right) e^{\text{-}\frac{(x-y)^2}{4Dt}} \int_{\text{-}\infty}^\infty \mathrm{d}y\,\frac{1}{\sqrt{4\pi Dt}} \, h(y)
# $$
#
# and the equation is a solution.

# %% [markdown]
# <div class="alert alert-block alert-info">Exercise 3.2</div>
#
# We have the probability of finding a particle at position $x$ in a potential landscape $V(x)$ given by
#
# $$
# P(x) = Z e^{-\beta V(x)},
# $$
#
# and hereby find the probability of moving one step to the right $p^+$
#
# $$
# p^+ = \frac{P(x_0 + 1)}{P(x_0) + P(x_0 + 1) + P(x_0 -1)},
# $$
#
# $$
# \quad \quad \, \, \, \, \quad = \frac{Z e^{-\beta V(x_0 + 1)}}{Z e^{-\beta V(x_0)} + Z e^{-\beta V(x_0 + 1)} + Z e^{-\beta V(x_0 - 1)}},
# $$
#
# which can be simplified to (3)
#
# $$
# p^+ = \frac{1}{1 + e^{-\beta [V(x_0) - V(x_0+1)]} + e^{-\beta [V(x_0 - 1)-V(x_0+1)]}}.
# $$
#
# Similarly, we have the probailities of staying put, $p^0$, and moving one step to the left, $p^-$ given by equations (4) and (5) respectively
#
# $$
# p^0 = \frac{1}{1 + e^{-\beta [V(x_0+1) - V(x_0)]} + e^{-\beta [V(x_0 - 1)-V(x_0)]}}.
# $$
#
# $$
# p^- = \frac{1}{1 + e^{-\beta [V(x_0) - V(x_0-1)]} + e^{-\beta [V(x_0 + 1)-V(x_0-1)]}},
# $$

# %% [markdown]
# <div class="alert alert-block alert-info">Exercise 3.3</div>
#
# By first exploring the latter condition, $k_B T \ll |V(x+1)-V(x)| \forall x$,
#
# $$
# \Rightarrow \left\{exp(-\beta \, [V(x_0-1)-V(x_0)], exp(-\beta\,[V(x_0+1)-V(x_0)] \right\} \rightarrow 0
# $$
#
# $$
# \therefore p^0 \rightarrow 1 \\
# \sum_{+, 0, -} p^i = 1 \Leftrightarrow p^+, p^- \rightarrow 0
# $$

# %% [markdown]
# which can also be proven by the following set of arguments (first looking at $p^+$)
#
# $$
# \left. e^{\, \text{-} \beta\, [V(x)-V(x+1)]} \rightarrow 0 \quad \therefore \,\, p^+ = \frac{1}{1 + e^{-\beta\, [V(x) - V(x+1)]}}\,\, \right\vert \, \cdot \frac{e^{-\,\beta\,V(x-1)}}{e^{\, \text{-}\,\beta\,V(x-1)}}
# $$
#
# $$
# \left. = \frac{e^{\,\text{-}\beta\,V(x-1)}}{1 + e^{\,\text{-}\beta\, [V(x) - V(x+1)]}}\,\, \right\vert \, \cdot \frac{e^{\,\text{-}\beta\,V(x-1)}}{e^{\,\text{-}\beta\,V(x-1)}}
# $$
#
# $$
# \Rightarrow \frac{e^{\, \text{-}\beta[V(x)-V(x-1)]}}{e^{\, \text{-}\beta[V(x)-V(x-1)}+e^{,\ \text{-}\beta [V(x)-V(x+1)]}}= \frac{e^{\, \text{-}\beta[V(x)-V(x-1)]}}{e^{\, \text{-}\beta[V(x)-V(x-1)}+e^{\beta [V(x+1)-V(x)]}}=\frac{1}{\infty} \rightarrow 0
# $$

# %% [markdown]
# **When $k_B t \gg [V(x+1)-V(x)]$**:
#
# $$
# p^0=\frac{1}{1+e^0+e^0}=\frac13
# $$
#
# $$
# \left. p^+ =\frac{1}{2+e^{\, \text{-}\beta [V(x-1)-V(x+1)]}} \right\vert \, \cdot \frac{e^{\, \text{-}\beta V(x)}}{e^{\, \text{-}\beta V(x)}}\\
#  p^+=\frac{e^{\, \text{-}\beta V(x)}}{2e^{\, \text{-}\beta V(x)}+e^{\, \text{-}\beta[V(x-1)+V(x)-V(x+1)]}}=\frac{e^{\, \text{-}\beta [V(x)-V(x-1)]}}{2e^{\, \text{-}\beta [V(x)-V(x-1)]}+e^{\, \text{-}\beta [V(x)-V(x+1)]}}
# $$
#
# $$
# =\frac{e^{\, \text{-}\beta [V(x)-V(x-1)]}}{2e^{\, \text{-}\beta [V(x)-V(x-1)]}+e^{\beta [V(x+1)-V(x)]}}=\frac13
# $$

# %% [markdown]
# <div class="alert alert-block alert-info">Exercise 4</div>

# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.stats import norm

particles = 10000
#beta = 1/(1.38064852*10**(-23)*298)
kb = [0.01, 1, 100] #k * beta
x = np.linspace(-200,200,400)
T = 200 #tidsintervall

def p_minus(x, kb, V):
    return 1/(1 + math.exp(-kb*(V(x+1)-V(x-1)))+math.exp(-kb*(V(x)-V(x-1))))

def p_zero(x, kb, V): #Unused, may be removed
        return 1/(1 + math.exp(-kb*(V(x-1)-V(x)))+math.exp(-kb*(V(x+1)-V(x))))

def p_plus(x, kb, V):
    return 1/(1 + math.exp(-kb*(V(x-1)-V(x+1)))+math.exp(-kb*(V(x)-V(x+1))))

# %%
def rand_walk(kb, T, V):
    x = 0 #x0
    left = 0
    right = 0
    for i in range(0, T):
        rNum = random.random()
        if (rNum) <= p_minus(x, kb, V):
            x-=1 #Move 1 step to the left
            #left += 1
            #print("venstre")
        elif (rNum) > (1-p_plus(x, kb, V)):
            x+=1 #Move 1 step to the right
            #print("høyre")
            #right += 1
        else:
            x+=0 #Does nothing but for readability
            #print(":)")
    return x#, left, right

# %%
def normalPlot(points):
    mu, std = norm.fit(points)
    p = norm.pdf(x,mu,std)
    plt.plot(x,p,'k')
    (unique, counts) = np.unique(points, return_counts=True)
    counts = counts/particles #Scales points relative to normal distribution
    plt.plot(unique, counts, 'o', linewidth=None)
    plt.show()

# %%
#NOTE: Run cell over before running this
############# 4.1  ############# - Constant potential
def V_const(x):
    return 1 #Defining V(x)/k in reality

xvals = np.zeros(10000) #Empty np-set

for i in range(int(particles)):
        xvals[i] = rand_walk(kb[0], T, V_const)#.x
plt.title("$V=k,\, kb=0.01$")
normalPlot(xvals)

#kb=1
for i in range(int(particles)):
    xvals[i] = rand_walk(kb[1], T, V_const)#.x det funker vel ikke.. + ugunstig

plt.title("$V=k,\, kb=1$")
normalPlot(xvals)


#kb=100
for i in range(int(particles)):
    xvals[i] = rand_walk(kb[2], T, V_const)
plt.title("$V=k,\, kb=100$")
normalPlot(xvals)

# %% [markdown]
# **KOMMENTAR PÅ $V=k$**
#
#
# The above graphs illustrate the particle distribution and its normal fit curve when the particles are in one dimension and subject to a constant potential $V=k$. These illustrations are based on $T=200$ timesteps. We observe that the different $\beta_k$ values does not affect the normal distribution curve whatsoever.
#
# **GANSKE GENERELT:**
# $\beta_k$ is the ratio of $k$ to $k_B T$, which in this case is a ratio that tells us something about how the distribution of the particles are influenced by the potential they are in and the thermal energy of the particles.
#
# It can also be interpreted from the equations (3), (4), and (5) that a constant potential will lead the power $[V(x+1)-V(x)] \, = \, 0$, so that the potential that the particles are subject to, will _not_ influence their distribution.
#
# Hence, one can conclude that, in a constant potential field, the thermal energy of the particles dominates the probability distribution of the particle motion. However, since the distributions are marginally influenced by the change in $\beta_k$, the thermal energy of the particles is seen to be insignificant (?????????????????????????????????????????????????????????) on its impact to the probability distribution of the particle motion.
#
# Concludingly, $\beta_k$ cannot be used as a ratio to determine whether the potential or thermal energy dominates the random walk.

# %%
############# 4.2  ############# - Linear potential
def V_lin(x):
    return x #kx

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[0], T, V_lin)

plt.title("$V=kx,\, kb=0.01$")
normalPlot(xvals)

#kb=1
for i in range(int(particles)):
    xvals[i] = rand_walk(kb[1], T, V_lin)

plt.title("$V=kx,\, kb=1$")
normalPlot(xvals)

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[2], T, V_lin)

plt.title("$V=kx,\, kb=100$, without normal distribution")
(unique, counts) = np.unique(xvals, return_counts=True)
counts = counts/particles
plt.plot(unique, counts, 'o', linewidth=None)
plt.show()

# %% [markdown]
# **KOMMENTAR PÅ 4.2**
#
# The above graphs illustrate the particle distribution and its normal fit curve when the particles are in one dimension and subject to a linear potential $V=kx$. These illustrations are based on $T=200$ timesteps. We observe that the different $\beta_k$ values to shift the normal distribution curve: The change in the fitted curves is a tendency to the left as the ratio $\beta_k$ increases.
#
# Increasing $\beta_k$ means that the ratio of potential to thermal energy increases. The particle diffusion is proportional to the negative of the potential gradient, meaning that the particle motion will always tend towards an area of subject to minimal potential. Since the potential increases proportionally with $x$, the particle motion will tend towards $-x$ which is defined to be leftwards. Moreover, increasing $\beta_k$ is equivalent to reducing the thermal energy of the particles. Hence, the thermal energy has negligible contribution to the particle distribution, and it is said that the potential that the particles are subject to, dominates their distribution.

# %%
############# 4.3  ############# 
def V_sine(x):
    return (x/20+np.sin(x/5))

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[0], T, V_sine)
plt.title("$kb=0.01$")
normalPlot(xvals)

#kb=1
for i in range(int(particles)):
    xvals[i] = rand_walk(kb[1], T, V_sine)
plt.title("$kb=1$")
normalPlot(xvals)

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[2], T, V_sine)
plt.title("$kb=100$")
normalPlot(xvals)


#Extra task 4.3
def V(x):
    return (x/20+np.sin(x/5))

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[0], T, V_sine) #200 time steps kb=0.01
    xvals[i] += rand_walk(kb[1], T, V_sine) #200 time steps kb=100
(unique, counts) = np.unique(xvals, return_counts=True)
counts = counts/particles
plt.plot(unique, counts, 'o', linewidth=None)
plt.title("Extra:")
plt.show()
print("The points in this case are closer to a normal distribution than both one run of kb=0.01 and one run of kb=100.")
# Out:
# The points in this case are closer to a normal distribution than both one run of kb=0.01 and one run of kb=100.

# %% [markdown]
# **KOMMENTAR PÅ 4.3**
#
# The above graphs illustrate the particle distribution and its normal fit curve when the particles are in one dimension and subject to a sinusoidal potential $V=\frac{x}{20}+\sin(\frac{x}{5})$. These illustrations are based on $T=200$ timesteps. We observe that the different $\beta_k$ values significantly affect the normal distribution curve.
#
#
# As $\beta_k$ increases, the fitted curves change to become narrower and their peaks achieve a greater maximum.
#
# When running the 'Extra' simulation in a potential with $\beta_k = 0.01$ for $T=200$ prior to a potential with $\beta_k = 100$ for the same timespan, the probability distribution of the particle motion is very similar to the probability distribution in $\beta_k = 0.01$ in shape, however it is slightly shiftet leftwards. This is explained by that 'Extra' is a simulation ran in a sum of potentials with ratio $\beta_k = 0.01$ and $\beta_k = 100$. The particle distribution with the latter $\beta_k$ is concentrated about $\text{-}10 \, - \, \text{-}8$. Thus, the sum of the probability distributions should be as in $\beta_k = 0.01$, but slightly shifted in $-x$ direction, q.e.d.

# %%
############# 4.4  ############# 

def V_squared(x):
    return x*x #Faster runtime than x**2

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[0], T, V_squared)
plt.title("$kb=0.01$")
normalPlot(xvals)

#kb=1
for i in range(int(particles)):
    xvals[i] = rand_walk(kb[1], T, V_squared)
plt.title("$kb=1$")
normalPlot(xvals)

for i in range(int(particles)):
    xvals[i] = rand_walk(kb[2], T, V_squared)
plt.title("$kb=100$")
normalPlot(xvals)
# Out:
# C:\Users\saabn\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1652: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %% [markdown]
# **KOMMENTAR PÅ 4.4**
#
#
# The above graphs illustrate the particle distribution and its normal fit curve when the particles are in one dimension and subject to a quadratic potential $V=kx^2$. These illustrations are based on $T=200$ timesteps. We observe that the different $\beta_k$ values to affect the normal distribution curve: The fitted curve changes to become narrower, and its peak value increase with an increased $\beta_k$.
#
# Increasing $\beta_k$ means that the ratio of potential to thermal energy increases. The particle diffusion is proportional to the negative of the potential gradient, meaning that the particle motion will always tend towards the nearest local area where the particles are subject to minimal potential. Since the potential increases proportionally with $x^2$, the particle motion will tend towards $x=0$, which is defined by that the particles will stay put. For lower values of $\beta_k$, the contribution from the potential to the particle distribution is smaller. This is argumented for by that a smaller $\beta_k$ coefficient to the quadratic potential will lead a less steep potential, meaning that the potential gradient becomes smaller in value, and the distribution of the particles is more diffuted than for a greater $\beta_k$.
#
# Moreover, increasing $\beta_k$ is equivalent to reducing the thermal energy of the particles. Hence, the for low values of $\beta_k$, the thermal energy has a greater contribution to the particle distribution than for greater values of $\beta_k$. In the latter condition, the thermal energy has negligible contribution to the particle distribution, and it is said that the potential that the particles are subject to, dominates their distribution. However, for low values of $\beta_k$, it is still not concludable whether the thermal energy or the potential that the particles are subject to dominates their distribution.

# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt

b= 1000 #skal man definere denne slik?


def p_pluss5(x,pot):
    return 1/(1 + np.exp(-b*(pot(x-1)-pot(x+1)))+np.exp(-b*(pot(x)-pot(x+1))))

def p_minus5(x,pot):
    return 1/(1 + np.exp(-b*(pot(x+1)-pot(x-1)))+np.exp(-b*(pot(x)-pot(x-1))))

#Sagtann funk.
def V_1(x):
    k=1
    a = 0.8
    N_x = 90
    if x>0:
        if x<a*N_x or x>(2*(-(1-a)*N_x)+a*N_x):
            return k*x/(a*N_x)
        else: 
            return -k*x/((1-a)*N_x)
    elif x<=0:
        return -k*x/((1-a)*N_x)
   
    
#konstant funk. satt til 1
def V_2(x):
    return 1


def time(pot,x):
    left = 0
    right = 0
    h = 1
    N_x = 90
    J=0
    rand_walk = random.random()
    if rand_walk <= p_minus5(x, pot):
        left+=1
        J-=h
        return left, J
    elif rand_walk > (1-p_pluss5(x,pot)):
        right+=1
        J+=h
        return right, J
    else:
        return 0, 0 #riktig?
    
    while x>2*N_x:
        x-=2*N_x
    while x<-(1-a)*N_x:
        x+=2*N_x


def cycle():
    t_inter = 100 #skal være 1000
    cycles = 10
    j_ti = []
    x = 0 #starter i null
    J=0
    N_p=12*1018 #ant partikler 
    position = np.floor(np.linspace(0,180,num=1080,endpoint=False)) #posisjonen til alle partiklene
    for i in range(cycles):
        for h in range(t_inter):
            if t_inter>= 50: #skal være 500
                potential = V_1
            else:
                potential = V_2
            for i in range(1080):
                pos, current = time(potential, position[i]) #int
                position[i]+=pos
                J+=current
        one_cycle = J/N_p 
        j_ti.append(one_cycle) #adding normalized particle current for each cycle
    print(j_ti)

    
#vil den nye posisjonen x lagres for hver iterasjon i denne koden?
cycle()

# %%
############# 6.1  ############# UFERDIG

from scipy import special
import matplotlib.pyplot as plt
import numpy as np

#6.1
def J_avg_analytical(alpha, Nx, Tp): #Analytical current as a function of alpha when Tp = 500\n",
    J = np.zeros(50)
    #for i in range(0, 50):
        #J[i] = (Nx/(4*Tp)* (special.erfc(alpha[i]*Nx/2 * np.sqrt(3/Tp)) - special.erfc((1-alpha[i])*Nx/2 * np.sqrt(3/Tp))))
    J = (Nx/(4*Tp)* (special.erfc(alpha*Nx/2 * np.sqrt(3/Tp)) - special.erfc((1-alpha)*Nx/2 * np.sqrt(3/Tp))))
    return J
Np = particles/2
Nx6_1 = Np/12
Tp6_1 = 500
alpha6_1 = np.linspace(0, 1, 50)

#plotting 6.1 and 5.3
def plotTask6_1():
    plt.figure()
    plt.plot(alpha6_1, J_avg_analytical(alpha6_1, Nx6_1, Tp6_1), label = '$J_{avg, analytical}$', 'b')
    #plot 5.3, farge 'r')
    plt.xlabel(r'$\alpha$')
    plt.ylabel('Current, $J_{avg}$')
    plt.legend()
    plt.show()

plotTask6_1()

# %% [markdown]
# **KOMMENTAR 6.1**

# %%
############# 6.2  ############# UFERDIG

#5.2
Nx5_2 = 10
Tp5_2 = np.linspace(80, 1500, 20)
alpha5_2 = 0.8

#plotter 5_2 og 6_2 hvis verdier av 5_2 blir brukt
plt.plot(Tp5_2, J_avg_analytical(alpha5_2, Nx5_2, Tp5_2), label = '$J_{avg, analytical}$', 'b')
plt.plot(Tp5_2, 
         ####################################
         , label = '$J_{avg, numerical}$', 'r')
plt.xlabel('$T_p$')
plt.ylabel('Current, $J_{avg}$')
plt.legend()
plt.show()

# %%
############# 6.3  ############# UFERDIG

kb = [0.01, 1, 2, 3, 5, 10]

for element in kb:
    plotTask6_1()

.
